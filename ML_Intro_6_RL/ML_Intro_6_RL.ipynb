# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({'Apple': [.4], 'Watermellon':[.3], 'Pear':[.3]}, index=['Prediction Weight']).T

# %%
df.plot.bar(label='words', figsize=[10,5])
plt.ylabel('probabilities')
plt.xlabel('predicted words')
plt.savefig('predictions')
